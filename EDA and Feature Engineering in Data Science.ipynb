# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.pandas.set_option('display.max_columns',None)

# %%
df=pd.read_csv('https://raw.githubusercontent.com/tiwari91/Housing-Prices/master/train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# # Missing Value

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
[x for x in df.columns ]
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
features_with_nan=[x for x in df.columns  if df[x].isnull().sum()>1]
features_with_nan
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
df['Electrical'].isnull().mean()
# Out:
# 0.0006849315068493151

# %%
for x in features_with_nan:
    print(x,(np.round(df[x].isnull().mean(),4)), "% missing values")
# Out:
# LotFrontage 0.1774 % missing values
# Alley 0.9377 % missing values
# MasVnrType 0.0055 % missing values
# MasVnrArea 0.0055 % missing values
# BsmtQual 0.0253 % missing values
# BsmtCond 0.0253 % missing values
# BsmtExposure 0.026 % missing values
# BsmtFinType1 0.0253 % missing values
# BsmtFinType2 0.026 % missing values
# FireplaceQu 0.4726 % missing values
# GarageType 0.0555 % missing values
# GarageYrBlt 0.0555 % missing values
# GarageFinish 0.0555 % missing values
# GarageQual 0.0555 % missing values
# GarageCond 0.0555 % missing values
# PoolQC 0.9952 % missing values
# Fence 0.8075 % missing values
# MiscFeature 0.963 % missing values

# %%
for x in features_with_nan:
    data=df.copy()
    data[x]=np.where(data[x].isnull(),1,0)
    data.groupby(x)['SalePrice'].median().plot.bar()
    plt.title(x)
    plt.show()

# %%
sns.boxplot(df['SalePrice'])
# There are many outliers in sales price as we can see in the box plot that why we use median
# Out:
# C:\Users\1933958\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SalePrice'>

# %% [markdown]
#  There are some relation b/w missing values and salesprice.. It is highly dependent

# %% [markdown]
# # Numerical Variables

# %%
# list of numerical variables
df['SaleType'].dtypes!='object'
# Out:
# False

# %%
numerical_features=[x for x in df.columns if df[x].dtypes!='O']

# %%
len(numerical_features)
# Out:
# 38

# %%
df[numerical_features]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
# Temporal Variables--Date time Variables
year_fearture=[x for x in numerical_features if 'Yr' in x or 'Year' in x]
year_fearture
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for x in year_fearture:
    print(x,df[x].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
df.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median house price')
plt.title('House Price Vs Year Sold')
# Out:
# Text(0.5, 1.0, 'House Price Vs Year Sold')

# %%
# Here we will compare the diff b/w all year feature with sale price
for x in year_fearture:
    if x!='YrSold':
        df[x]=df['YrSold']- df[x]
        plt.scatter(df[x],df['SalePrice'])
        plt.xlabel(x)
        plt.ylabel('SalePrice')
        plt.show()

# %%
### new houses are more costlier that older ones

# %%
# numerical variables are of 2 types

# %%
discrete_feature=[x for x in numerical_features if len(df[x].unique()) <25]
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
# find relation b/w discrete and sales price
data=df.copy()
for x in discrete_feature:
    data.groupby(x)['SalePrice'].median().plot.bar()
    plt.xlabel(x)
    plt.ylabel("Sales Price")
    plt.title(x)
    plt.show()

# %%
###Continous Variables
continous_feature=[x for x in numerical_features if x not in discrete_feature+year_fearture]
continous_feature
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
# Lets analyise contious by using histrogram to find the distribution
data=df.copy();
for x in continous_feature:
    data[x].hist(bins=25)
    plt.xlabel(x);
    plt.ylabel("Count")
    plt.show()

# %%
## EDA PART 2
## we will be using lograthmic transdormation
data=df.copy();
for x in continous_feature:
    if 0 in data[x].unique():
        pass
    else:
        data[x]=np.log(data[x])
        plt.scatter(data[x],data['SalePrice'])
        plt.xlabel(x)
        plt.ylabel("Sale Price")
        plt.show()

# %%
##Outliers

# %%
data=df.copy()
for x in continous_feature:
    if 0 in data[x].unique():
        pass
    else:
        data[x]=np.log(data[x])
        data.boxplot(column=x)
        plt.ylabel(x)
        plt.xlabel(x)
        plt.show()

# %%
data=df.copy()
data['SalePrice'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data['SalePrice'],kde=True)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# # Categorical Variables

# %%
cateogrical_feature=[x for x in df.columns if df[x].dtypes=="O"]
cateogrical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df[cateogrical_feature]
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
for x in cateogrical_feature:
    print("The feature name is {} and the number of categories are {}".format(x,len(df[x].unique())))
# Out:
# The feature name is MSZoning and the number of categories are 5
# The feature name is Street and the number of categories are 2
# The feature name is Alley and the number of categories are 3
# The feature name is LotShape and the number of categories are 4
# The feature name is LandContour and the number of categories are 4
# The feature name is Utilities and the number of categories are 2
# The feature name is LotConfig and the number of categories are 5
# The feature name is LandSlope and the number of categories are 3
# The feature name is Neighborhood and the number of categories are 25
# The feature name is Condition1 and the number of categories are 9
# The feature name is Condition2 and the number of categories are 8
# The feature name is BldgType and the number of categories are 5
# The feature name is HouseStyle and the number of categories are 8
# The feature name is RoofStyle and the number of categories are 6
# ...

# %%
data=df.copy()
for x in cateogrical_feature:
    data.groupby(x)['SalePrice'].median().plot.bar()
    plt.xlabel(x)
    plt.ylabel("sale Price")
    plt.show()

# %% [markdown]
# # EDA PART-2

# %%
dataFrame=pd.read_csv('https://raw.githubusercontent.com/shwetachandel/Black-Friday-Dataset/master/Black%20Friday%20Dataset/train.csv')

# %%
dataFrame.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
numerical_var=[x for x in dataFrame.columns if dataFrame[x].dtypes !="O"]
numerical_var
# Out:
# ['User_ID',
#  'Occupation',
#  'Marital_Status',
#  'Product_Category_1',
#  'Product_Category_2',
#  'Product_Category_3',
#  'Purchase']

# %%
cateogrical_var=[x for x in dataFrame.columns if dataFrame[x].dtypes =="O"]
cateogrical_var
# Out:
# ['Product_ID', 'Gender', 'Age', 'City_Category', 'Stay_In_Current_City_Years']

# %%
#Feature Engineering

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# X=df.drop(["Id","SalePrice"],axis=1)
# y=df['SalePrice']

# %%
X=df.iloc[:,1:81]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1352          50       RM         50.0     6000   Pave   NaN      Reg
# 1037          60       RL          NaN     9240   Pave   NaN      Reg
# 154           30       RM         84.0    11340   Pave   NaN      Reg
# 497           50       RL         60.0     9120   Pave  Pave      Reg
# 442           50       RM         52.0     6240   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1261          20       RL         80.0     9600   Pave   NaN      Reg
# 347           20       RL          NaN    17600   Pave   NaN      IR1
# 1153          30       RM          NaN     5890   Pave   NaN      Reg
# 791           80       RL          NaN    11333   Pave   NaN      IR1
# 415           20       RL         73.0     8899   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
X_test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 405           20       RL          NaN     9991   Pave   NaN      IR1
# 1375          20       RL         89.0    10991   Pave   NaN      IR1
# 352           50       RL         60.0     9084   Pave   NaN      Reg
# 266           60       RL         70.0    11207   Pave   NaN      IR1
# 661           60       RL         52.0    46589   Pave   NaN      IR2
# ...          ...      ...          ...      ...    ...   ...      ...
# 720          120       RL          NaN     6563   Pave   NaN      IR1
# 690          120       RM          NaN     4426   Pave   NaN      Reg
# 1193         120       RM          NaN     4500   Pave   NaN      Reg
# 798           60       RL        104.0    13518   Pave   NaN      Reg
# 957           20       RL         70.0     7420   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
# Misssing valurs

# %%
missing_feature=[x for x in df.columns if df[x].isnull().sum()>0]
for x in missing_feature:
    print("The feature is {} and missing values is {}".format(x,np.round(df[x].isnull().mean(),4)))
# Out:
# The feature is LotFrontage and missing values is 0.1774
# The feature is Alley and missing values is 0.9377
# The feature is MasVnrType and missing values is 0.0055
# The feature is MasVnrArea and missing values is 0.0055
# The feature is BsmtQual and missing values is 0.0253
# The feature is BsmtCond and missing values is 0.0253
# The feature is BsmtExposure and missing values is 0.026
# The feature is BsmtFinType1 and missing values is 0.0253
# The feature is BsmtFinType2 and missing values is 0.026
# The feature is Electrical and missing values is 0.0007
# The feature is FireplaceQu and missing values is 0.4726
# The feature is GarageType and missing values is 0.0555
# The feature is GarageYrBlt and missing values is 0.0555
# The feature is GarageFinish and missing values is 0.0555
# The feature is GarageQual and missing values is 0.0555
# The feature is GarageCond and missing values is 0.0555
# The feature is PoolQC and missing values is 0.9952
# ...

# %%
#Numerical Features

# %%
numerical_features_nan=[x for x in df.columns if df[x].dtype!="O" and df[x].isnull().sum()>=1]
numerical_features_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
for x in numerical_features_nan:
    ## Since there are outliers we are going to preplace with median
    median_values=df[x].median()
    df[x+'nan']=np.where(df[x].isnull(),1,0)
    df[x].fillna(median_values,inplace=True)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
#Temporal Variable

# %%
year_feature=[x for x in df.columns if 'Yr' in x or 'Year' in x]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold', 'GarageYrBltnan']

# %%
for x in year_feature:
    df[x + "Age of House"]=df['YrSold']-df[x]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Challenge

# %%
dfNew=pd.read_excel('Data_Train (3).xlsx')
dfNew
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dfNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
dfNew.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
dfNew['Date']=dfNew['Date_of_Journey'].str.split('/').str[0]
dfNew['Month']=dfNew['Date_of_Journey'].str.split('/').str[1]
dfNew['Year']=dfNew['Date_of_Journey'].str.split('/').str[2]

# %%
dfNew
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
# OR
dfNew['Date_of_Journey'].apply(lambda x:x.split("/")[0])
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date_of_Journey, Length: 10683, dtype: object

# %%
dfNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
#  11  Date             10683 non-null  object
#  12  Month            10683 non-null  object
#  13  Year             10683 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 1.1+ MB

# %%
dfNew['Date']=dfNew['Date'].astype(int)
dfNew['Month']=dfNew['Month'].astype(int)
dfNew['Year']=dfNew['Year'].astype(int)

# %%
dfNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
#  11  Date             10683 non-null  int32
#  12  Month            10683 non-null  int32
#  13  Year             10683 non-null  int32
# dtypes: int32(3), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
dfNew
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# ...

# %%
dfNew['Arrival_Time'].str.split(' ')
# Out:
# 0        [01:10, 22, Mar]
# 1                 [13:15]
# 2        [04:25, 10, Jun]
# 3                 [23:30]
# 4                 [21:35]
#                ...
# 10678             [22:25]
# 10679             [23:20]
# 10680             [11:20]
# 10681             [14:10]
# 10682             [19:15]
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dfNew['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dfNew['Arrival_Hours']=dfNew['Arrival_Time'].str.split(' ').str[0].str.split(':').str[0]
dfNew['Arrival_Mins']=dfNew['Arrival_Time'].str.split(' ').str[0].str.split(':').str[1]

# %%
dfNew
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# ...

# %%
dfNew.drop('Mins',axis=1,inplace=True)

# %%
dfNew
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#       Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# ...

# %%
dfNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Duration         10683 non-null  object
#  6   Total_Stops      10682 non-null  object
#  7   Additional_Info  10683 non-null  object
#  8   Price            10683 non-null  int64
#  9   Date             10683 non-null  int32
#  10  Month            10683 non-null  int32
#  11  Year             10683 non-null  int32
#  12  Hours            10683 non-null  object
#  13  Mins             10683 non-null  object
#  14  Arrival_Hours    10683 non-null  object
#  15  Arrival_Mins     10683 non-null  object
# dtypes: int32(3), int64(1), object(12)
# ...

# %%
dfNew['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
dfNew['Total_Stops']=dfNew['Total_Stops'].map({'non-stop':0,'1 stop':1,'3 stops':3,'2 stops':2,'4 stops':4,'nan':1})

# %%
dfNew['Total_Stops'].mode()
# Out:
# 0    1 stop
# Name: Total_Stops, dtype: object

# %%
dfNew.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#    Total_Stops Additional_Info  Price  Date  Month  Year Arrival_Hours  \
# 0          0.0         No info   3897    24      3  2019            01
# 1          2.0         No info   7662     1      5  2019            13
# 2          2.0         No info  13882     9      6  2019            04
# 3          1.0         No info   6218    12      5  2019            23
# 4          1.0         No info  13302     1      3  2019            21
#
#   Arrival_Mins
# 0           10
# 1           15
# 2           25
# ...

# %%
dfNew.drop('Route',axis=1,inplace=True)

# %%
dfNew
# Out:
#            Airline    Source Destination Dep_Time Duration  Total_Stops  \
# 0           IndiGo  Banglore   New Delhi    22:20   2h 50m          0.0
# 1        Air India   Kolkata    Banglore    05:50   7h 25m          2.0
# 2      Jet Airways     Delhi      Cochin    09:25      19h          2.0
# 3           IndiGo   Kolkata    Banglore    18:05   5h 25m          1.0
# 4           IndiGo  Banglore   New Delhi    16:50   4h 45m          1.0
# ...            ...       ...         ...      ...      ...          ...
# 10678     Air Asia   Kolkata    Banglore    19:55   2h 30m          0.0
# 10679    Air India   Kolkata    Banglore    20:45   2h 35m          0.0
# 10680  Jet Airways  Banglore       Delhi    08:20       3h          0.0
# 10681      Vistara  Banglore   New Delhi    11:30   2h 40m          0.0
# 10682    Air India     Delhi      Cochin    10:55   8h 20m          2.0
#
#       Additional_Info  Price  Date  Month  Year Arrival_Hours Arrival_Mins
# ...

# %%
len(dfNew['Airline'].unique())
# Out:
# 12

# %%
# one hot encoding
df_new=pd.get_dummies(dfNew,columns=["Additional_Info","Airline","Source","Destination"],drop_first=True)

# %%
df_new
# Out:
#       Dep_Time Duration  Total_Stops  Price  Date  Month  Year Arrival_Hours  \
# 0        22:20   2h 50m          0.0   3897    24      3  2019            01
# 1        05:50   7h 25m          2.0   7662     1      5  2019            13
# 2        09:25      19h          2.0  13882     9      6  2019            04
# 3        18:05   5h 25m          1.0   6218    12      5  2019            23
# 4        16:50   4h 45m          1.0  13302     1      3  2019            21
# ...        ...      ...          ...    ...   ...    ...   ...           ...
# 10678    19:55   2h 30m          0.0   4107     9      4  2019            22
# 10679    20:45   2h 35m          0.0   4145    27      4  2019            23
# 10680    08:20       3h          0.0   7229    27      4  2019            11
# 10681    11:30   2h 40m          0.0  12648     1      3  2019            14
# 10682    10:55   8h 20m          2.0  11753     9      5  2019            19
#
# ...
